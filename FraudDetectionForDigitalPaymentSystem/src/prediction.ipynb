# %%
import main

class prediction:

    # Logistic LogisticRegression
    def getPredictedLogisticRegModel(X_train, y_train):
        model = main.getLogisticsReg()
        model.fit(X_train, y_train)
        return model


    #Decision Tree
    def getDecesionTreePredictedModel(X_train, y_train,criterion,max_depth):
        model = main.getDecesionTree(criterion,max_depth)
        model.fit(X_train, y_train)
        return model


    # Random RandomForestClassifier
    def getRandomForestPredictedModel(X_train, y_train,n_estimators,random_state):
        model = main.getRandomForest(n_estimators,random_state)
        model.fit(X_train, y_train)
        return model


    # XG Boost
    def getXgBoostPredictedModel(X_train, y_train,n_estimators, max_depth, learning_rate):
        model = main.getXgBoost(n_estimators, max_depth, learning_rate)
        model.fit(X_train, y_train)
        return model

     # Logistic LogisticRegression  With Grid Search
    def getPredictedLogisticRegModelWithGridSearch(X_train, y_train):
        grid = main.getLogisticsRegWithGridSearch()
        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        return best_model


    #Decision Tree  With Grid Search
    def getDecesionTreePredictedModelWithGridSearch(X_train, y_train,criterion,max_depth):
        model = main.getDecesionTreeWithGridSearch(criterion,max_depth)
        grid_search.fit(X_train, y_train)
        best_dt = grid_search.best_estimator_
        print(f"Best Parameters: {grid_search.best_params_}")
        return best_dt


    # Random RandomForestClassifier  With Grid Search
    def getRandomForestPredictedModelWithGridSearch(X_train, y_train,n_estimators,random_state):
        grid_search = main.getRandomForestWithGridSearch(n_estimators,random_state)
        grid_search.fit(X_train, y_train)
        best_rf = grid_search.best_estimator_
        print(f"Best Parameters: {grid_search.best_params_}")
        return best_rf


    # XG Boost With Grid Search
    def getXgBoostPredictedModelWithGridSearch(X_train, y_train,n_estimators, max_depth, learning_rate):
        grid_search.fit(X_train, y_train)
        best_xgb = grid_search.best_estimator_
        print(f"Best Parameters: {grid_search.best_params_}")
        return best_xgb
